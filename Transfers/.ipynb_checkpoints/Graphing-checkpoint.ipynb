# %% [markdown]
# <h1> Data Graphing for Pointcloud Transfer Speeds </h1>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib notebook
#Probably more useful to show how speeds can vary per file size than a true line graph. Also useful to overlay them

# %%
df1 = pd.read_csv('transfer_data.csv', sep=',', header=0, names=["FILE_SIZE", "BYTES_PER_SECOND"])
df1.values
# Out:
# array([[1.04857600e+06, 8.42084975e+05],
#        [1.04857600e+06, 8.76615581e+05],
#        [1.04857600e+06, 8.59501910e+05],
#        [1.04857600e+06, 8.72196136e+05],
#        [1.04857600e+06, 8.52918951e+05],
#        [1.04857600e+07, 4.28964216e+06],
#        [1.04857600e+07, 4.58130517e+06],
#        [1.04857600e+07, 4.41764977e+06],
#        [1.04857600e+07, 4.50136748e+06],
#        [1.04857600e+07, 4.25700284e+06],
#        [1.04857600e+08, 8.69721872e+06],
#        [1.04857600e+08, 8.87308857e+06],
#        [1.04857600e+08, 8.79860172e+06],
#        [1.04857600e+08, 8.77522181e+06],
#        [1.04857600e+08, 8.77524604e+06],
#        [1.04857600e+09, 9.38199133e+06],
#        [1.04857600e+09, 9.47662800e+06],
#        [1.04857600e+09, 9.60034530e+06],
#        [1.04857600e+09, 9.43235972e+06],
#        [1.04857600e+09, 9.48418450e+06],
#        [1.04857600e+10, 9.41187805e+06],
#        [1.04857600e+10, 9.45871316e+06],
#        [1.04857600e+10, 9.26747950e+06],
# ...

# %%
ax = df1.plot(kind='line',x='FILE_SIZE',y='BYTES_PER_SECOND',color='green', title="b/s for non-file type", legend=False)
ax.set_ylabel("BYTES_PER_SEC")
ax.set_xlabel("FILE_SIZE_IN_BYTES")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df['BYTES_PER_SECOND'] = df['BYTES_PER_SECOND'] / 1000000
df['FILE_SIZE'] = df['FILE_SIZE'] / 1000000
ax = df.plot(kind='line',x='FILE_SIZE',y='BYTES_PER_SECOND',color='green', title="b/s for non-file type", legend=False)
ax.set_ylabel("MB_PER_SEC")
ax.set_xlabel("FILE_SIZE_IN_MB")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.read_csv('transfer_data_txt.csv', sep=',', header=0, names=["FILE_SIZE", "BYTES_PER_SECOND"])
df.values
# Out:
# array([[1.04857600e+06, 6.99641164e+05],
#        [1.04857600e+06, 8.52602016e+05],
#        [1.04857600e+06, 8.53058422e+05],
#        [1.04857600e+06, 8.42208072e+05],
#        [1.04857600e+07, 4.65987800e+06],
#        [1.04857600e+07, 3.32368683e+06],
#        [1.04857600e+07, 4.43984708e+06],
#        [1.04857600e+07, 3.45471798e+06],
#        [1.04857600e+07, 3.58763493e+06],
#        [1.04857600e+08, 8.12613262e+06],
#        [1.04857600e+08, 8.18162021e+06],
#        [1.04857600e+08, 8.03009571e+06],
#        [1.04857600e+08, 8.30177870e+06],
#        [1.04857600e+08, 7.49426839e+06],
#        [1.04857600e+09, 9.04294977e+06],
#        [1.04857600e+09, 9.21657520e+06],
#        [1.04857600e+09, 9.20459457e+06],
#        [1.04857600e+09, 8.50345685e+06],
#        [1.04857600e+09, 8.53557573e+06],
#        [1.04857600e+10, 9.69188618e+06],
#        [1.04857600e+10, 9.84744107e+06],
#        [1.04857600e+10, 9.79120838e+06],
#        [1.04857600e+10, 1.01874217e+07],
# ...

# %%
ax = df.plot(kind='line',x='FILE_SIZE',y='BYTES_PER_SECOND',color='green', title="b/s for txt type", legend=False)
ax.set_ylabel("BYTES_PER_SEC")
ax.set_xlabel("FILE_SIZE_IN_BYTES")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df['BYTES_PER_SECOND'] = df['BYTES_PER_SECOND'] / 1000000
df['FILE_SIZE'] = df['FILE_SIZE'] / 1000000
ax = df.plot(kind='line',x='FILE_SIZE',y='BYTES_PER_SECOND',color='green', title="b/s for txt type", legend=False)
ax.set_ylabel("MB_PER_SEC")
ax.set_xlabel("FILE_SIZE_IN_MB")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.read_csv('transfer_data_ply.csv', sep=',', header=0, names=["FILE_SIZE", "BYTES_PER_SECOND"])
df.values
# Out:
# array([[1.04857600e+06, 8.51530899e+05],
#        [1.04857600e+06, 8.81817295e+05],
#        [1.04857600e+06, 8.50117719e+05],
#        [1.04857600e+06, 7.36190496e+05],
#        [1.04857600e+07, 4.53398273e+06],
#        [1.04857600e+07, 4.67416291e+06],
#        [1.04857600e+07, 4.60271183e+06],
#        [1.04857600e+07, 4.49931625e+06],
#        [1.04857600e+07, 4.20411641e+06],
#        [1.04857600e+08, 9.28671343e+06],
#        [1.04857600e+08, 9.22870840e+06],
#        [1.04857600e+08, 9.42280028e+06],
#        [1.04857600e+08, 9.27107981e+06],
#        [1.04857600e+08, 9.03986754e+06],
#        [1.04857600e+09, 9.67318713e+06],
#        [1.04857600e+09, 9.92316197e+06],
#        [1.04857600e+09, 9.84454778e+06],
#        [1.04857600e+09, 9.91750417e+06],
#        [1.04857600e+09, 9.46917486e+06],
#        [1.04857600e+10, 1.00903365e+07],
#        [1.04857600e+10, 9.80559243e+06],
#        [1.04857600e+10, 9.58350254e+06],
#        [1.04857600e+10, 9.81671591e+06],
# ...

# %%
ax = df.plot(kind='line',x='FILE_SIZE',y='BYTES_PER_SECOND',color='green', title="b/s for ply type", legend=False)
ax.set_ylabel("BYTES_PER_SEC")
ax.set_xlabel("FILE_SIZE_IN_BYTES")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df['BYTES_PER_SECOND'] = df['BYTES_PER_SECOND'] / 1000000
df['FILE_SIZE'] = df['FILE_SIZE'] / 1000000
ax = df.plot(kind='line',x='FILE_SIZE',y='BYTES_PER_SECOND',color='green', title="b/s for ply type", legend=False)
ax.set_ylabel("MB_PER_SEC")
ax.set_xlabel("FILE_SIZE_IN_MB")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Need to keep pointclouds UNDER 1000 megabytes

# %%
ax = df.plot(kind='bar',x='FILE_SIZE',y='BYTES_PER_SECOND',color='green', title="b/s for ply type", legend=False)
ax.set_ylabel("MB_PER_SEC")
ax.set_xlabel("FILE_SIZE_IN_MB")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df1 = pd.read_csv('transfer_data.csv', sep=',', header=0, names=["FILE_SIZE", "BYTES_PER_SECOND"])
df2 = pd.read_csv('transfer_data_ply.csv', sep=',', header=0, names=["FILE_SIZE", "BYTES_PER_SECOND"])
df3 = pd.read_csv('transfer_data_txt.csv', sep=',', header=0, names=["FILE_SIZE", "BYTES_PER_SECOND"])
ax = df1.plot(kind='line',x='FILE_SIZE',y='BYTES_PER_SECOND',color='blue', label="NO FILE TYPE")
ax.set_ylabel("BYTES_PER_SEC")
ax.set_xlabel("FILE_SIZE_IN_MB")
df2.plot(ax=ax, kind='line',x='FILE_SIZE',y='BYTES_PER_SECOND',color='purple', label="PLY")
df3.plot(ax=ax, kind='line',x='FILE_SIZE',y='BYTES_PER_SECOND',color='red', label="TXT")
# Out:
# <img src="data:image/png;base64,..." width="640">
