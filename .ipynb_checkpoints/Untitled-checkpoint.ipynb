# %% [markdown]
# <h1> Data Graphing for Pointcloud Transfer Speeds </h1>

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
x = np.linspace(0,10,20)
y = x**2
plt.plot(x,y)
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'y')

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_axes([0.1, 0.2, 0.8, 0.9])

# %%
ax.plot(x,y, 'purple')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Object Oriented')
# Out:
# Text(0.5, 1, 'Object Oriented')
